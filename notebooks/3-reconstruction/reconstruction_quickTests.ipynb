# %% [markdown]
# # Reconstruction

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>NOTE:</strong> This is done on a PC where I don't need X11 forwarding (since <code>mayavi</code> is a graphic package, and the lab's server doesn't support X11).
# </div>

# %% [markdown]
# Reference: https://tomroelandts.com/articles/astra-toolbox-tutorial-reconstruction-from-projection-images-part-2

# %%
# !pip install mayavi

# %%
from numba import cuda
cuda.select_device(0)
cuda.close()

# %%
import numpy as np
from os import mkdir
from os.path import join, isdir
from imageio import imread, imwrite
import matplotlib.pyplot as plt
import astra
import h5py
import os
import mrcfile
#from tvtk.api import tvtk
from mayavi import mlab
from IPython.display import Image
import sys
sys.path.append("../..") 
from cryoem.reconstruction import reconstruct
from cryoem.conversions import quaternion2euler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-e19df41cd86c> in <module>
#       9 import mrcfile
#      10 #from tvtk.api import tvtk
# ---> 11 from mayavi import mlab
#      12 from IPython.display import Image
#      13 import sys
#
# ModuleNotFoundError: No module named 'mayavi'

# %% [markdown]
# ---

# %% [markdown]
# # Predicted Angles and Projections (Variance 0.3)

# %% [markdown]
# ## Reconstruction

# %%
angles_predicted = np.load("../1-phase1/data/5j0n/predicted_angles_var03.npy")
reconstruction = reconstruct(projections[:3000], angles_predicted[:3000], mrc_filename=None)

# %%
mlab.contour3d(reconstruction, transparent=True)
mlab.colorbar(orientation='vertical')
# mlab.savefig("data/5a1a_projections_and_angles.tiff")
mlab.show()

# %%
Image(filename='data/5j0n_projections_and_angles_predicted_var03.png')

# %% [markdown]
# ## After Angle Alignment

# %%
angles_predicted = np.load("../1-phase1/data/5j0n/predicted_angles_var03_updated.npy")
reconstruction = reconstruct(projections[:3000], angles_predicted[:3000], mrc_filename=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-0e93812a1d79> in <module>
# ----> 1 angles_predicted = np.load("../1-phase1/data/5j0n/predicted_angles_var03_updated.npy")
#       2 reconstruction = reconstruct(projections[:3000], angles_predicted[:3000], mrc_filename=None)
#
# ~/anaconda3/envs/protein_reconstruction/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '../1-phase1/data/5j0n/predicted_angles_var03_updated.npy'

# %%
mlab.contour3d(reconstruction, transparent=True)
mlab.colorbar(orientation='vertical')
# mlab.savefig("data/5a1a_projections_and_angles.tiff")
mlab.show()

# %%
Image(filename='data/5j0n_projections_and_angles_predicted_var03_updated.png')

# %% [markdown]
# ---
