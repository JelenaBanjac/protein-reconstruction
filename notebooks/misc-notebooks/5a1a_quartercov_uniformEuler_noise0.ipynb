# %% [markdown]
# # Reconstruction

# %%
from numba import cuda
cuda.select_device(0)
cuda.close()

# %%
import numpy as np
from os import mkdir
from os.path import join, isdir
from imageio import imread, imwrite
import matplotlib.pyplot as plt
import astra
import h5py
import os
import mrcfile
#from tvtk.api import tvtk
from mayavi import mlab
from IPython.display import Image
import sys
sys.path.append("../..") 
from cryoem.reconstruction import reconstruct
from cryoem.conversions import quaternion2euler
# Out:
# Warning: To use the exr data format, please install the OpenEXR package following the instructions detailed in the README at github.com/tensorflow/graphics.
# Warning: To use the threejs_vizualization, please install the colabtools package following the instructions detailed in the README at github.com/tensorflow/graphics.

# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1743654420967155229
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17110328892619409170
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2692781690986165787
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2092630016
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 287337979735125799
# physical_device_desc: "device: 0, name: GeForce GTX 1050 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# ---

# %%
RESULTS_DIR = "../../data/results_pipeline_5a1a_quartercov_uniformEuler_noise0"
initial_mrc_filename = "../../data/5a1a.mrc"
prefix = "5a1a_quartercov_uniformEuler_noise0"

# %%
data = np.load(f"{RESULTS_DIR}/train_val_test_indices.npz")
train_idx, val_idx, test_idx = data['arr_0'], data['arr_1'], data['arr_2']

# %%
# file with projections and angles
projections_filename = f"{RESULTS_DIR}/5a1a_ProjectionsAngles_ProjNber5000_AngCoverage2.0,1.0,0.5_AngShift0.0,0.0,0.0.h5"

# load structures
data = h5py.File(projections_filename, 'r')
projections = data["Projections"]
angles_true = data['Angles']

# %% [markdown]
# # Reconstruction with Ground-Truth Angles

# %%
reconstruction = reconstruct(projections[test_idx], 
                             angles_true[test_idx], 
                             mrc_filename=f"{RESULTS_DIR}/{prefix}_gt.mrc", 
                             initial_mrc_filename=initial_mrc_filename, 
                             overwrite=True)
# Out:
# Reconstruction voxel size: (1., 1., 1.)
# Initial voxel size: (1., 1., 1.)
# Reconstruction saved to: ../../data/results_pipeline_5a1a_quartercov_uniformEuler_noise0/5a1a_quartercov_uniformEuler_noise0_gt.mrc

# %%
# uncomment if you want to see the mayavi reconstruction visualization, we use chimera
# mlab.contour3d(reconstruction, transparent=True)
# mlab.colorbar(orientation='vertical')
# mlab.show()

# %%
Image(filename=f'{RESULTS_DIR}/{prefix}_gt.png')

# %% [markdown]
# ---

# %% [markdown]
# # Reconstruction with Random Angles

# %%
angles_random = np.random.rand(*angles_true.shape)
angles_random = np.multiply(angles_random, np.max(angles_true, axis=0))

reconstruction = reconstruct(projections[test_idx], 
                             angles_random[test_idx], 
                             mrc_filename=f"{RESULTS_DIR}/{prefix}_rand.mrc", 
                             initial_mrc_filename=initial_mrc_filename, 
                             overwrite=True)
# Out:
# Reconstruction saved to: ../../data/results_pipeline_5a1a_quartercov_uniformEuler_noise0/5a1a_quartercov_uniformEuler_noise0_rand.mrc

# %%
# uncomment if you want to see the mayavi reconstruction visualization, we use chimera
# mlab.contour3d(reconstruction, transparent=True)
# mlab.colorbar(orientation='vertical')
# mlab.show()

# %%
Image(filename=f'{RESULTS_DIR}/{prefix}_rand.png')

# %% [markdown]
# ---

# %% [markdown]
# # Reconstruction before Angle Alignment

# %%
angles_predicted = np.load(f"{RESULTS_DIR}/5a1a_angles_predicted.npy")
reconstruction = reconstruct(projections[test_idx], 
                             angles_predicted[test_idx], 
                             mrc_filename=f"{RESULTS_DIR}/{prefix}_ap.mrc", 
                             initial_mrc_filename=initial_mrc_filename, 
                             overwrite=True)
# Out:
# Reconstruction saved to: ../../data/results_pipeline_5a1a_quartercov_uniformEuler_noise0/5a1a_quartercov_uniformEuler_noise0_ap.mrc

# %%
# uncomment if you want to see the mayavi reconstruction visualization, we use chimera
# mlab.contour3d(reconstruction, transparent=True)
# mlab.colorbar(orientation='vertical')
# mlab.show()

# %%
Image(filename=f'{RESULTS_DIR}/{prefix}_ap.png')

# %% [markdown]
# # Reconstruction after Angle Alignment

# %%
#projections = np.load("data/projections.npy")
angles_predicted = np.load(f"{RESULTS_DIR}/5a1a_angles_predicted_rotated.npy")
reconstruction = reconstruct(projections[test_idx][:1100], 
                             angles_predicted[test_idx][:1100], 
                             mrc_filename=f"{RESULTS_DIR}/{prefix}_apr.mrc", 
                             initial_mrc_filename=initial_mrc_filename, 
                             alg_iterations=1000,
                             overwrite=True)
# Out:
# Reconstruction voxel size: (1., 1., 1.)
# Initial voxel size: (1., 1., 1.)
# Reconstruction saved to: ../../data/results_pipeline_5a1a_quartercov_uniformEuler_noise0/5a1a_quartercov_uniformEuler_noise0_apr.mrc

# %%
# uncomment if you want to see the mayavi reconstruction visualization, we use chimera
# mlab.contour3d(reconstruction, transparent=True)
# mlab.colorbar(orientation='vertical')
# mlab.show()

# %%
Image(filename=f'{RESULTS_DIR}/{prefix}_apr.png')

# %% [markdown]
# ---

# %%
Image(filename=f'{RESULTS_DIR}/{prefix}_FSC_apr_init.png')
